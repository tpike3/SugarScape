# %%
import pickle
import matplotlib.pyplot as plt
from scipy.stats.mstats import gmean
import seaborn as sns
# %matplotlib inline


price = pickle.load(open("price_record.p", "rb"))

# %%
len(price[2])
# Out:
# 321

# %%
## Calculate price

# %%
x = []
y =[]

for st, pr in price.items(): 
    #if step <=400: 
        x.append(st)
        y.append(gmean(pr))
        
y[0]
# Out:
# 1.0276794465094066

# %%
fig, ax = plt.subplots(figsize = (7,7))
ax.scatter(x,y)
plt.title("Explicit Approach:\nMean Trade Price", fontsize = 20, fontweight = "bold")
plt.xlabel("Time", fontsize = 15, fontweight = "bold")
plt.ylabel("Price", fontsize = 15, fontweight = "bold")
# Out:
# Text(0,0.5,'Price')

# %%
x_vol = []
y_vol = []
total = 0
for s, p in price.items(): 
    #if step <=400:
        
        x_vol.append(s)
        y_vol.append(len(p))
        total += len(p)
total
# Out:
# 3210

# %%
fig2, ax2 = plt.subplots(figsize = (7,7))
ax2.hist(y_vol, 100)
plt.title("Trade Volume Histogram", fontsize = 20, fontweight = "bold")
plt.xlabel("Trade Volume of Step", fontsize = 15, fontweight = "bold")
plt.ylabel("Frequency Trade Volume", fontsize = 15, fontweight = "bold")
#plt.ylim(0,400)
# Out:
# Text(0,0.5,'Frequency Trade Volume')

# %%
fig2, ax2 = plt.subplots(figsize = (7,7))
ax2.plot(x_vol, y_vol)
plt.title("Explicit Approach:\nTrade Volume", fontsize = 20, fontweight = "bold")
plt.xlabel("Time", fontsize = 15, fontweight = "bold")
plt.ylabel("Volume", fontsize = 15, fontweight = "bold")
ax2.text(600,300, "Total Trade Volume: \n "+str(total), fontsize = 15, fontweight = 'bold')
#plt.ylim(0,400)
# Out:
# Text(600,300,'Total Trade Volume: \n 3210')

# %%
from statistics import stdev
from math import log
x_dev =[]
y_dev = []
x_all = []
y_all = []
log_prices = {}
mean_prices = {}
for step,prices in price.items(): 
        mean_prices[step] = gmean(prices)
for step, prices in price.items(): 
    log_prices[step] = [abs(log(p)) for p in prices]
for step, log_p in log_prices.items(): 
    #if step <= 400: 
        
        
        if len(log_p) <2: 
            pass       
        else:            
            x_dev.append(step)
            y_dev.append(stdev(log_p))
'''            
for step, mean_p in mean_prices.items():
    x_all.append(step)
    y_all.append(mean_p)
'''
# Out:
# '            \nfor step, mean_p in mean_prices.items():\n    x_all.append(step)\n    y_all.append(mean_p)\n'

# %%
from numpy.polynomial.polynomial import polyfit
fig3, ax3 = plt.subplots(figsize=(7,7))
#plt.plot(x_all,z,color='red', label = "Logarithmic Price")
ax3.scatter(x_dev,y_dev, color ='blue', label = "Standard Deviation Logarithmic Mean")
plt.title("Explicit Approach: \nStandard Deviation of Logarithmic Mean", fontsize = 20, fontweight = "bold")
plt.xlabel("Time", fontsize = 15, fontweight = "bold")
plt.ylabel("Logarithmic Price", fontsize = 15, fontweight = "bold")
plt.legend()

# %%
import numpy as np
np.random.randint(1,6, 20)
# Out:
# array([5, 1, 2, 5, 2, 4, 5, 3, 3, 2, 4, 5, 4, 1, 4, 3, 2, 2, 2, 2])
